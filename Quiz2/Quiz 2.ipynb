# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Shuai Cheng David Lai")
# Out:
# Shuai Cheng David Lai

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code

fifa = pd.read_csv("data_quiz/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Use queries + global variables
#
# <font size = "3">
#
# - Subset the players whose value of the column "On Loan" is "YES" <br>
# and store it in a new dataset
# - How many players are on loan?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. <br>
# Reference the column as ``` `On Loan` ``` inside .query()

# %%
# Write your own code

display(fifa)
newdataset = fifa.query("`On Loan == @YES`")
pd.count(newdataset)
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Skill Moves  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            4
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...            4
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...            4
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...            4
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...            5
# ...                                                 ...  ...          ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...            2
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...            2
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...            2
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...            2
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            2
#
#        International Reputation  National Team Name  \
# 0                             5           Argentina
# 1                             4              France
# 2                             5              Poland
# 3                             4             Belgium
# 4                             4              France
# ...                         ...                 ...
# 18534                         1                   -
# 18535                         1                   -
# 18536                         1                   -
# 18537                         1                   -
# 18538                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 0                              10                  Low                  Low
# 1                              19               Medium               Medium
# 2                               9                 High               Medium
# 3                               7                 High                 High
# 4                              10                 High                  Low
# ...                           ...                  ...                  ...
# 18534                           -               Medium               Medium
# 18535                           -               Medium               Medium
# 18536                           -                 High               Medium
# 18537                           -               Medium               Medium
# 18538                           -               Medium               Medium
#
#       player_classification random_var
# 0             Top Performer   0.321286
# 1             Top Performer   0.704979
# 2             Top Performer   0.811969
# 3             Top Performer   0.962239
# 4             Top Performer   0.831882
# ...                     ...        ...
# 18534     Non Top-Performer   0.224445
# 18535     Non Top-Performer   0.399896
# 18536     Non Top-Performer   0.468264
# 18537     Non Top-Performer   0.493558
# 18538     Non Top-Performer   0.856325
#
# [18539 rows x 35 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:233, in Scope.resolve(self, key, is_local)
#     232 if self.has_resolvers:
# --> 233     return self.resolvers[key]
#     235 # if we're here that means that we have no locals and we also have
#     236 # no resolvers
#
# File c:\Users\HONOR\anaconda3\Lib\collections\__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# File c:\Users\HONOR\anaconda3\Lib\collections\__init__.py:998, in ChainMap.__missing__(self, key)
#     997 def __missing__(self, key):
# --> 998     raise KeyError(key)
#
# KeyError: 'BACKTICK_QUOTED_STRING_On_Loan__EQUAL__EQUAL__YES'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     240 try:
#     241     # last ditch effort we look in temporaries
#     242     # these are created when parsing indexing expressions
#     243     # e.g., df[df > 0]
# --> 244     return self.temps[key]
#     245 except KeyError as err:
#
# KeyError: 'BACKTICK_QUOTED_STRING_On_Loan__EQUAL__EQUAL__YES'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[55], line 4
#       1 # Write your own code
#       3 display(fifa)
# ----> 4 newdataset = fifa.query("`On Loan == YES`")
#       5 pd.count(newdataset)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\frame.py:4440, in DataFrame.query(self, expr, inplace, **kwargs)
#    4438 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4439 kwargs["target"] = None
# -> 4440 res = self.eval(expr, **kwargs)
#    4442 try:
#    4443     result = self.loc[res]
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\frame.py:4566, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4563     kwargs["target"] = self
#    4564 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4566 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:548, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     547 def visit_Name(self, node, **kwargs):
# --> 548     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:86, in Term.__init__(self, name, env, side, encoding)
#      84 tname = str(name)
#      85 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86 self._value = self._resolve_name()
#      87 self.encoding = encoding
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:110, in Term._resolve_name(self)
#     105 if local_name in self.env.scope and isinstance(
#     106     self.env.scope[local_name], type
#     107 ):
#     108     is_local = False
# --> 110 res = self.env.resolve(local_name, is_local=is_local)
#     111 self.update(res)
#     113 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\Users\HONOR\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:246, in Scope.resolve(self, key, is_local)
#     244     return self.temps[key]
#     245 except KeyError as err:
# --> 246     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'BACKTICK_QUOTED_STRING_On_Loan__EQUAL__EQUAL__YES' is not defined

# %% [markdown]
# <font size = "5">
#
# (b) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "Overall"
# - If "Overall > 90", classification = "Top Performer"
# - If "Overall <= 90", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "Overall" in the dataset <br>
# (be carefeful to write the "O" capitalized)
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_agebracket(Overall):
    if (Overall > 90):
        Overall = "Top Performer"
    else:
        Overall = "Non Top-Performer"
    return(Overall)
fifa["player_classification"] =  fifa["Overall"].apply(fn_agebracket)
display(fifa["player_classification"])
# Out:
# 0            Top Performer
# 1            Top Performer
# 2            Top Performer
# 3            Top Performer
# 4            Top Performer
#                ...
# 18534    Non Top-Performer
# 18535    Non Top-Performer
# 18536    Non Top-Performer
# 18537    Non Top-Performer
# 18538    Non Top-Performer
# Name: player_classification, Length: 18539, dtype: object

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Joined On" shows the date in which each player joined FIFA
# - Use ".sort_values()" to order the "Joined On" column <br>
# from earlier data to later date
# - Get a subset with the 6 players in the dataset <br>
# who joined FIFA earliest
# - From this subset, display the year in which they joined <br>
# by displaying the column "Joined On"

# %%
# Write your own code
carsorted = fifa.sort_values(by = "Joined On", ascending = True)
display(carsorted.iloc[:6, : ])
earliest_players =  carsorted.iloc[:6, : ]
print(earliest_players["Joined On"])
# Out:
#        Unnamed: 0       Known As        Full Name  Overall  Potential  \
# 8586         8586   D. Lewington   Dean Lewington       66         66
# 10877       10877    P. Karlsson     Per Karlsson       64         64
# 4324         4324       I. Khune  Itumeleng Khune       70         70
# 11056       11056    Cai Huikang      Huikang Cai       64         64
# 10360       10360   L. Stevenson  Lewis Stevenson       65         65
# 11768       11768  Wang Shenchao    Shenchao Wang       64         64
#
#        Value(in Euro) Positions Played Best Position   Nationality  \
# 8586           150000               CB           CDM       England
# 10877          100000               CB            CB        Sweden
# 4324           180000               GK            GK  South Africa
# 11056          400000           CDM,CM            CB      China PR
# 10360          250000               LB            LB      Scotland
# 11768          275000            CB,RM            CB      China PR
#
#                                              Image Link  ...  \
# 8586   https://cdn.sofifa.net/players/138/830/23_60.png  ...
# 10877  https://cdn.sofifa.net/players/176/717/23_60.png  ...
# 4324   https://cdn.sofifa.net/players/165/247/23_60.png  ...
# 11056  https://cdn.sofifa.net/players/224/608/23_60.png  ...
# 10360  https://cdn.sofifa.net/players/175/316/23_60.png  ...
# 11768  https://cdn.sofifa.net/players/224/604/23_60.png  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 8586                  3            2                         1
# 10877                 3            2                         1
# 4324                  5            1                         2
# 11056                 3            3                         1
# 10360                 3            2                         1
# 11768                 4            3                         1
#
#        National Team Name                 National Team Image Link  \
# 8586                    -  https://cdn.sofifa.net/flags/gb-eng.png
# 10877                   -      https://cdn.sofifa.net/flags/se.png
# 4324                    -      https://cdn.sofifa.net/flags/za.png
# 11056                   -                                        -
# 10360                   -  https://cdn.sofifa.net/flags/gb-sct.png
# 11768            China PR                                        -
#
#       National Team Position  National Team Jersey Number  \
# 8586                       -                            -
# 10877                      -                            -
# 4324                       -                            -
# 11056                      -                            -
# 10360                      -                            -
# 11768                     RB                            4
#
#        Attacking Work Rate Defensive Work Rate player_classification
# 8586                  High              Medium     Non Top-Performer
# 10877                  Low                High     Non Top-Performer
# 4324                Medium              Medium     Non Top-Performer
# 11056                  Low                High     Non Top-Performer
# 10360                 High                High     Non Top-Performer
# 11768                 High                High     Non Top-Performer
#
# [6 rows x 34 columns]
# 8586     2002
# 10877    2003
# 4324     2004
# 11056    2005
# 10360    2005
# 11768    2005
# Name: Joined On, dtype: int64

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Potential" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code
model = smf.ols(formula = 'Potential ~  Age', data = fifa)
results = model.fit()
b_list = results.params
print(b_list)
# Out:
# Intercept    79.752454
# Age          -0.346103
# dtype: float64

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.5```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.5```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
import pandas as pd
import numpy as np

# Given number of rows
n = 18888

# Create a sample dataset with n rows and some arbitrary number of columns
# For demonstration purposes, let's create a DataFrame with 3 columns
df = pd.DataFrame()

# Create a random variable column drawn from a uniform distribution between 0 and 1 with size n
df['random_var'] = np.random.uniform(0, 1, size=n)

# Subset the data using .query() into two datasets
data0 = df.query('random_var < 0.5')
data1 = df.query('random_var >= 0.5')

# Check the first few rows of each subset to ensure the operation was successful
data0.head(), data1.head(), len(data0), len(data1)
# Out:
# (    random_var
#  5     0.134176
#  13    0.254059
#  17    0.310049
#  19    0.236341
#  24    0.300357,
#     random_var
#  0    0.785933
#  1    0.803245
#  2    0.515291
#  3    0.550946
#  4    0.626734,
#  9506,
#  9382)

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display the distribution of "Age" for "data0" and "data1" using <br>
# ```plt.hist()```
# - You will need to label the axes, and the title
# - To get full points, plot the histograms with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" vector instead of ```...``` <br>
# (The alpha option sets the transparency of the histogram )
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code
plt.hist( x= data1)
plt.title("under 0.5")
plt.ylabel("Frequency")
plt.show()
plt.hist(x = data0)
plt.title("over 0.5")
plt.ylabel("Frequency")
plt.show()
